# %%
#variable creation
a = 56 #numeric-Integer
b = 56.5 #numeric-Float
c = "sdfjsha 948567058xmcvlkgf" #string(sequence of characters)

# %%
#Area of Rectangle
w = 45.54
h = 32.52
area  = w * h
print(area)
round(area,3)
# Out:
# 1480.9608
# 1480.961

# %%
#Area of Triangle
w = 45.54
h = 32.52
area  = 1/2 * (w * h)
print(area)
round(area,2)
# Out:
# 740.4804
# 740.48

# %%
#Area of Triangle
w = float (input("Input Width: "))
h = float(input("Input Height: "))

print("Types ", type(w) , type(h) )
area  = 1/2 * (w * h)
print(area)
round(area,2)
# Out:
# Input Width: 3.6
# Input Height: 3.8
# Types  <class 'float'> <class 'float'>
# 6.84
# 6.84

# %%
35

# %%
x = input('Please enter your name:')
# Out:
# Please enter your name:hasnain

# %%
x
# Out:
# 'hasnain'

# %%
num1 =int(input('Please enter your first number:'))
num2 =int(input('Please enter your second number:'))
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print ('Addition is  :', addition , 'subtraction is:', subtraction , 'multiplication is: ', multiplication , 'division is: ', division)
# Out:
# Please enter your first number:5
# Please enter your second number:10
# Addition is  : 15 subtraction is: -5 multiplication is:  50 division is:  0.5

# %%
marks= float(input('please enter your marks'))
percentage = marks / 110 * 100
print('my percentage is ', percentage)
# Out:
# please enter your marks77
# my percentage is  70.0

# %%
x = int(input('Please enter any number'))
if x>=0:
  print('The entered number is positive')
else:
  print('The entered number is negative')
# Out:
# Please enter any number0
# The entered number is positive

# %%
num1 = int(input('Please enter first number'))
num2 = int(input('Please enter second number'))
choice = int(input('Enter 1 for adiition and any other number for subtraction'))

if choice == 1:
  print('Addition is: ', num1 + num2)
else:
  print('Subtraction is: ', num1-num2)
# Out:
# Please enter first number10
# Please enter second number5
# Enter 1 for adiition and any other number for subtraction500
# Subtraction is:  5
