# %%
age = int(input("INput Your age: "))
perc = float(input("INput the percentage: "))
if (perc>=60 or age>=18 ):
  print("Selected ")
else:
  print("Not slected")
print("Hello")
# Out:
# INput Your age: 90
# INput the percentage: 45
# Selected
# Hello

# %%
t = int(input("INput Your temperature: "))
h = float(input("INput the humidity: "))
if (h>60 and t>35 ):
  print("BExtreme worst ")
elif (h>50 and t>30 ):
  print("Bad Atmosp")

else:
  print("Normal")
# Out:
# INput Your temperature: 40
# INput the humidity: 70
# Bad Atmosp

# %%
for n in range(1,11):
  print("Nimra")
# Out:
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra
# Nimra

# %%
#Average OF Marks
sum = 0
for n in range(1,5):
  m = int(input("Enter marks for Student: "))
  sum = sum + m
avg = sum/4
print("Average Marks = ",avg)
# Out:
# Enter marks for Student: 45
# Sum  45
# Enter marks for Student: 35
# Sum  80
# Enter marks for Student: 20
# Sum  100
# Enter marks for Student: 30
# Sum  130

# %%
#range(start=0, end is the mandatory parameter )
for i in range(4):
  print("Class ", i)
# Out:
# Class  0
# Class  1
# Class  2
# Class  3

# %%
#range(start, end, jump), start and jump are optional
#Default value of start=0, jump=1
print("Odd Numbers: ")
for i in range(1,10,2):
  print("Class ", i)
# Out:
# Odd Numbers:
# Class  1
# Class  3
# Class  5
# Class  7
# Class  9

# %%
#Average OF Marks
sum = 0
for n in range(1,5):
  m = int(input("Enter marks for Student: "))
  if (m>=60):
    print("Pass thi wayi ")
  else:
    print("Fail")
  sum = sum + m
avg = sum/4
print("Average Marks = ",avg)
# Out:
# Enter marks for Student: 67
# Pass thi wayi
# Enter marks for Student: 56
# Fail
# Enter marks for Student: 78
# Pass thi wayi
# Enter marks for Student: 34
# Fail
# Average Marks =  58.75

# %%
names = ["John", "Tom", "Ben 10", "Tweety"]
for n in names:
  print(n)
# Out:
# John
# Tom
# Ben 10
# Tweety
