# %% [markdown]
# ## normal distribution
#
#
# loc (float, optional):
#
# The mean (
# 𝜇
# μ) of the normal distribution.
# Default is 0.0.
# scale (float, optional):
#
# The standard deviation (
# 𝜎
# σ) of the distribution (spread or width).
# Default is 1.0.
# Must be a non-negative number.

# %%
import numpy as np
import matplotlib.pyplot as plt

normal_data = np.random.normal(loc=50, scale=10, size=500)
len(normal_data)
# Out:
# 500

# %%
plt.hist(normal_data, bins=30, density=True, alpha=0.6, color='g')
plt.title("Normal Distribution")
plt.show()

# %% [markdown]
# ## Uniform Distribution
# np.random.uniform(0, 100, 1000):
# Generates 1000 random numbers from a uniform distribution.
#
# The range is between 0 (inclusive) and 100 (exclusive).
#
# A uniform distribution means every number in the range [0, 100) has an equal probability of being selected.

# %%
uniform_data = np.random.uniform(0, 1, 1000)
plt.hist(uniform_data, bins=30, alpha=0.6, color='b')
plt.title("Uniform Distribution")
plt.show()

# %% [markdown]
# ## Binomial Distribution
#
# n = 10: Number of trials (repetitions of the experiment).
#
# p = 0.5: Probability of success in each trial (like flipping a fair coin).
#
# **binom.rvs(n, p, size=1000):**
# Generates 1000 random samples from a Binomial distribution.
#
# The distribution represents the number of successes in n=10 independent trials, where the probability of success is p=0.5.

# %%
from scipy.stats import binom
n, p = 10, 0.5  # Number of trials and probability of success
binomial_data = binom.rvs(n=n, p=p, size=1000)
print(binomial_data)
# Out:
# [ 3  5  6  5  6  4  8  6  1  4  7  5  3  3  7  8  5  7  6  5  4  4  5  7
#   5  6  5  7  3  6  2  6  4  4  5  6  6  6  6  4  7  3  5  3  4  5  4  1
#   8  4  6  1  7  5  4  3  3  5  2  7  2  8  3  5  4  5  5  7  6  4  2  5
#   4  6  4  4  7  3  6  4  5  2  7  5  5  7  6  3  6  7  5  3  6  6  6  6
#   6  6  3  3  4  4  7  6  6  7  5  4  4  7  5  3  5  3  2  6  6  5  5  6
#   5  4  5  6  5  6  2  5  6  8  2  5  5  8  5  6  7  5  5  5  8  4  5  4
#   5  2  5  4  4  7  4  5  5  3  4  6  7  7  6  7  3  2  4  7  3  3  9  6
#   5  4  6  3  4  5  5  7  5  8  4  4  5  5  2  3  6  5  6  6  9  4  3  1
#   6  5  4  9  8  4  4  2  2  3  2  2  2  6  5  4  3  6  4  6  5  4  3  4
#   4  3  5  6  7  6  3  4  3  6  4  5  6  3  5  5  2  6  5  2  2  5  5  9
#   6  5  6  4  7  4  3  4  6  6  6  7  1  6  4  7  3  3  6  5  7  3  6  7
#   6  4  6  3  7  5  8  4  7  5  8  5  6  5  4  5  5  6  6  5  5  6  5  6
#   4  6  7  4  5  5  7  6  5  6  8  5  6  6  7  2  4  4  7  5  3  3  5  6
# ...

# %%
plt.hist(binomial_data, bins=30, density=True, alpha=0.6, color='r')
plt.title("Binomial Distribution")
plt.show()

# %%
# Load the dataset
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/Collab-Learning/PITP_Data Science/Datasets/Employee_Productivity_Dataset.csv')
# Display the first few rows of the dataset
df.head()
# Out:
#    Employee_ID  Salary  Monthly_Hours_Worked  Performance_Score
# 0            1   45795                   170                  3
# 1            2   30860                   182                  7
# 2            3   84886                   171                 10
# 3            4   36265                   123                  9
# 4            5   67194                   142                  4

# %%
# Visualize the distribution of Salary using a histogram
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Salary'], kde=True, bins=30)
plt.title("Distribution of Salary")
plt.show()

# %% [markdown]
# # Visualizing Monthly Hours Worked Using KDE
#
# A KDE plot is used to visualize the distribution of the 'Monthly_Hours_Worked' feature. This plot shows the probability density of the data using a continuous curve.

# %%
# Visualize the distribution of Monthly Hours Worked using KDE
sns.kdeplot(df['Salary'], shade=True)
plt.title("KDE Plot for Monthly Hours Worked")
plt.show()
# Out:
# <ipython-input-20-77ebe02c9548>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Salary'], shade=True)

# %%
# Visualize the distribution of Monthly Hours Worked using KDE
sns.kdeplot(df['Monthly_Hours_Worked'], shade=True)
plt.title("KDE Plot for Monthly Hours Worked")
plt.show()
# Out:
# <ipython-input-21-63598b34590d>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Monthly_Hours_Worked'], shade=True)

# %%
# Visualize the distribution of Performance Score
sns.histplot(df['Performance_Score'], kde=True, bins=30)
plt.title("Distribution of Performance Score")
plt.show()

# %%
# Calculate and display the variance of Salary
variance_salary = df['Salary'].var()
print(f"Variance of Salary: {variance_salary}")
# Out:
# Variance of Salary: 503818844.58373725

# %%
# Calculate and display the variance of Salary
variance_salary = df['Salary'].var()
print(f"Variance of Salary: {variance_salary}")
# Out:
# Variance of Salary: 503818844.58373725

# %%
data  = [60, 65, 95, 121, 85]
variance = np.var(data)
print(variance)
# Out:
# 484.16

# %%
covariance = df[['Salary', 'Monthly_Hours_Worked']].cov()
print(f"Covariance between Salary and Performance Score:\n{covariance}")
# Out:
# Covariance between Salary and Performance Score:
#                             Salary  Monthly_Hours_Worked
# Salary                5.038188e+08          77431.107273
# Monthly_Hours_Worked  7.743111e+04            537.963232

# %%
covariance = df[['Salary', 'Performance_Score']].cov()
print(f"Covariance between Salary and Performance Score:\n{covariance}")
# Out:
# Covariance between Salary and Performance Score:
#                          Salary  Performance_Score
# Salary             5.038188e+08        -172.411717
# Performance_Score -1.724117e+02           7.873131
