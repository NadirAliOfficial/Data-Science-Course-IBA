# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Ella'],
    'Age': [25, 30, 35, 40, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'Salary': [70000, 80000, 120000, 110000, 95000]
}
df = pd.DataFrame(data)
df.head(4)
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   70000
# 1      Bob   30  Los Angeles   80000
# 2  Charlie   35      Chicago  120000
# 3    David   40      Houston  110000

# %%
df.to_csv("/content/drive/MyDrive/Collab-Learning/Employees.csv", index=False )
df.to_excel("/content/drive/MyDrive/Collab-Learning/Employees.xlsx", index = False)

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Collab-Learning/Employees.csv')
df1.head(2)
# Out:
#     Name  Age         City  Salary
# 0  Alice   25     New York   70000
# 1    Bob   30  Los Angeles   80000

# %%
#Select the Colum
df1['Age']
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    29
# Name: Age, dtype: int64

# %%
df['City']
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4        Phoenix
# Name: City, dtype: object

# %%
df1[['Age', 'Name']]
# Out:
#    Age     Name
# 0   25    Alice
# 1   30      Bob
# 2   35  Charlie
# 3   40    David
# 4   29     Ella

# %%
df1.iloc[0:3]
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   70000
# 1      Bob   30  Los Angeles   80000
# 2  Charlie   35      Chicago  120000

# %%
df1.query("Age<30")
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   70000
# 4   Ella   29   Phoenix   95000

# %%
df1.query("City=='New York' or City=='Los Angeles'")
# Out:
#     Name  Age         City  Salary
# 0  Alice   25     New York   70000
# 1    Bob   30  Los Angeles   80000

# %%
#Adding a new column
df1['Experience'] = [2, 5, 8, 10, 4]
df1.head(3)
# Out:
#       Name  Age         City  Salary  Experience
# 0    Alice   25     New York   70000           2
# 1      Bob   30  Los Angeles   80000           5
# 2  Charlie   35      Chicago  120000           8

# %%
df1['Tax'] = df1['Salary'] * 0.15
df1.head(3)
# Out:
#       Name  Age         City  Salary  Experience      Tax
# 0    Alice   25     New York   70000           2  10500.0
# 1      Bob   30  Los Angeles   80000           5  12000.0
# 2  Charlie   35      Chicago  120000           8  18000.0

# %%
# #Delete Column
# df1.drop('Experience', axis=1, inplace =True)
# df1.head(3)

# %%
# df1.drop(2, axis=0, inplace = True)
# df1.head(3)

# %%
df1.set_index('Name', inplace = True)
df1.head(3)
# Out:
#          Age         City  Salary  Experience      Tax
# Name
# Alice     25     New York   70000           2  10500.0
# Bob       30  Los Angeles   80000           5  12000.0
# Charlie   35      Chicago  120000           8  18000.0

# %%
df1.loc['Bob':]
# Out:
#          Age         City  Salary  Experience      Tax
# Name
# Bob       30  Los Angeles   80000           5  12000.0
# Charlie   35      Chicago  120000           8  18000.0
# David     40      Houston  110000          10  16500.0
# Ella      29      Phoenix   95000           4  14250.0

# %%
df1.reset_index(inplace = True)
df1.head(3)
# Out:
#       Name  Age         City  Salary  Experience      Tax
# 0    Alice   25     New York   70000           2  10500.0
# 1      Bob   30  Los Angeles   80000           5  12000.0
# 2  Charlie   35      Chicago  120000           8  18000.0
