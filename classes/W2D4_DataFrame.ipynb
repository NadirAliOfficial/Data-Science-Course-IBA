# %%
#Creating Dictionary
dictionary={
    'Name': ['Ahsan', 'rehman', 'Ali'],
    'Age': [20,25,30],
    'City': ['Sukkur', 'Karachi', 'Hydrabad']
}

# %%
import pandas as pd
data_frame= pd.DataFrame(dictionary)
data_frame
# Out:
#      Name  Age      City
# 0   Ahsan   20    Sukkur
# 1  rehman   25   Karachi
# 2     Ali   30  Hydrabad

# %%
#Indexing and Sliecing
filter = data_frame[data_frame['Age']> 20]
print(filter)
# Out:
#      Name  Age      City
# 1  rehman   25   Karachi
# 2     Ali   30  Hydrabad

# %%
#Filtering based on Age and City
filter = data_frame[(data_frame['Age']> 20) & ( data_frame['City']=='Sukkur')][['Name', 'Age', 'City']]
print(filter)
# Out:
#      Name   Age    City
# 3  Unkown  25.0  Sukkur

# %%
dictionary={
    'Name': ['Ahsan', 'rehman', None, None],
    'Age': [20,None,30, None],
    'City': ['Sukkur', 'Karachi', 'Hydrabad', "Sukkur"]
}
import pandas as pd
data_frame= pd.DataFrame(dictionary)
data_frame
# Out:
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman   NaN   Karachi
# 2    None  30.0  Hydrabad
# 3    None   NaN    Sukkur

# %%
#Filling NA values
data_frame['Name'].fillna('Unkown', inplace=True)
data_frame['Age'].fillna(data_frame['Age'].mean(), inplace=True)
data_frame
# Out:
# <ipython-input-13-6ee52c4c2bf2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_frame['Name'].fillna('Unkown', inplace=True)
# <ipython-input-13-6ee52c4c2bf2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_frame['Age'].fillna(data_frame['Age'].mean(), inplace=True)
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman  25.0   Karachi
# 2  Unkown  30.0  Hydrabad
# 3  Unkown  25.0    Sukkur

# %%
#Sorting the value using Age Column
sorted_table = data_frame.sort_values(by ='Age', ignore_index=True)
print(sorted_table)
# Out:
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman  25.0   Karachi
# 2  Unkown  25.0    Sukkur
# 3  Unkown  30.0  Hydrabad

# %%
#Filtering using City
filter_by_city=data_frame[data_frame['City']=='Sukkur'][['Name','Age']]
print(filter_by_city)
# Out:
#      Name   Age
# 0   Ahsan  20.0
# 3  Unkown  25.0

# %%
dictionary={
    'Name': ['Ahsan', 'rehman', None, None],
    'Age': [20,None,30, None],
    'City': ['Sukkur', 'Karachi', 'Hydrabad', "Sukkur"]
}
import pandas as pd
data_frame= pd.DataFrame(dictionary)
data_frame
# Out:
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman   NaN   Karachi
# 2    None  30.0  Hydrabad
# 3    None   NaN    Sukkur

# %%
#Creating and reading CSV file
data_frame.to_csv('data_frame.csv', index=False)
data_frame_read =pd.read_csv('data_frame.csv')
print(data_frame_read)
# Out:
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman   NaN   Karachi
# 2     NaN  30.0  Hydrabad
# 3     NaN   NaN    Sukkur

# %%
dictionary={
    'Name': ['Ahsan', 'rehman', None, None, 'Ali','rehan','hyder'],
    'Age': [20,None,30, None,20,10,50],
    'City': ['Sukkur', 'Karachi', 'Hydrabad', "Sukkur",'Pano Aqil', 'Rorhi','Sukkur']
}
import pandas as pd
data_frame= pd.DataFrame(dictionary)
data_frame
# Out:
#      Name   Age       City
# 0   Ahsan  20.0     Sukkur
# 1  rehman   NaN    Karachi
# 2    None  30.0   Hydrabad
# 3    None   NaN     Sukkur
# 4     Ali  20.0  Pano Aqil
# 5   rehan  10.0      Rorhi
# 6   hyder  50.0     Sukkur

# %%
#Feching the data using rows
print(data_frame.iloc[0])
# Out:
# Name     Ahsan
# Age       20.0
# City    Sukkur
# Name: 0, dtype: object

# %%
print(data_frame.iloc[:4,:3])
# Out:
#      Name   Age      City
# 0   Ahsan  20.0    Sukkur
# 1  rehman   NaN   Karachi
# 2    None  30.0  Hydrabad
# 3    None   NaN    Sukkur

# %%
#coloumm vise data

print(data_frame.loc[:2,['Name','City']])
# Out:
#      Name      City
# 0   Ahsan    Sukkur
# 1  rehman   Karachi
# 2    None  Hydrabad

# %%
#Merging the DataFrames
import pandas as pd
dic1={
    'ID': [1,2,3,4],
    'Name': ['Ahsan', 'rehman', 'Ali', 'bilal']
}

df1= pd.DataFrame(dic1)
df1
dic2={
    'ID': [1,2,3,5],
    'Score': [40,50,70,80]
}

df2= pd.DataFrame(dic2)
df2
# Out:
#    ID  Score
# 0   1     40
# 1   2     50
# 2   3     70
# 3   5     80

# %%
merge_data_frame=pd.merge(df1,df2,on='ID')
print(merge_data_frame)
# Out:
#    ID    Name  Score
# 0   1   Ahsan     40
# 1   2  rehman     50
# 2   3     Ali     70

# %%
import pandas as pd
