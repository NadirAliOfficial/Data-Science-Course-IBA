# %%
print('Week 3 Day 3')
# Out:
# Week 3 Day 3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "Name": ['Nadir', 'Faraz', 'Waheed', 'Raheela', "Siraj"],
    "Age": [20, 21, 24, 22, 120]
})

# %%
sorted_names = df.sort_values(by='Age', ascending=False)
sorted_names
# Out:
#       Name  Age
# 4    Siraj  120
# 2   Waheed   24
# 3  Raheela   22
# 1    Faraz   21
# 0    Nadir   20

# %%
data = pd.read_csv("../data/students_data.csv")

df = pd.DataFrame(data)
df.head()
# Out:
#    Student_ID First_Name Last_Name Grade  Age Enrollment_Date  \
# 0        3101       Emma     Scott     D   17      2017-10-01
# 1        3102    William    Turner     A   18      2020-02-24
# 2        3103      Lucas      Hill     F   18      2020-12-13
# 3        3104     Sophia    Wright     F   22      2022-04-22
# 4        3105       Liam  Anderson     B   18      2020-09-02
#
#               Major   GPA
# 0       Engineering  3.20
# 1        Psychology  2.05
# 2  Computer Science  3.71
# 3       Engineering  3.17
# 4               Art  2.10

# %%
df.shape
# Out:
# (150, 8)

# %%
df.isnull().sum()
# Out:
# Student_ID         0
# First_Name         0
# Last_Name          0
# Grade              0
# Age                0
# Enrollment_Date    0
# Major              0
# GPA                0
# dtype: int64

# %%
sorted_age = df.sort_values(by='Age')
sorted_age.head()
# Out:
#     Student_ID First_Name Last_Name Grade  Age Enrollment_Date  \
# 27        3128     Sophia    Turner     C   14      2022-10-12
# 22        3123     Olivia  Anderson     F   14      2022-05-30
# 58        3159   Isabella     Baker     F   14      2022-11-06
# 45        3146       Emma     Baker     B   14      2021-08-29
# 86        3187   Isabella     Clark     A   14      2019-04-15
#
#                Major   GPA
# 27           History  1.67
# 22              Math  2.16
# 58               Art  1.83
# 45  Computer Science  3.67
# 86               Art  3.17

# %%
q1 = df.Age.quantile(0.25)
q3 = df.Age.quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# np.float64(4.0)

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
upper_bound, lower_bound
# Out:
# (np.float64(26.0), np.float64(10.0))

# %%
# Out:
# Empty DataFrame
# Columns: [Student_ID, First_Name, Last_Name, Grade, Age, Enrollment_Date, Major, GPA]
# Index: []

# %%
df.loc[97, "Age"] = 150
df.loc[96, "Age"] = 0

# %%
df.loc[96:97]
# Out:
#     Student_ID First_Name Last_Name Grade  Age Enrollment_Date Major   GPA
# 96        3197       Emma     Adams     D    0      2020-08-13   Art  3.87
# 97        3198       Liam      Hill     C  150      2017-09-30   Art  2.14

# %%
outliers = df[(df.Age < lower_bound) | (df.Age > upper_bound)]
outliers
# Out:
#     Student_ID First_Name Last_Name Grade  Age Enrollment_Date Major   GPA
# 97        3198       Liam      Hill     C  150      2017-09-30   Art  2.14

# %%
import numpy as np    
replaced =  np.where(df.Age > upper_bound, upper_bound, np.where(df.Age < lower_bound, lower_bound, df.Age))

# %%
df.head(100)
# Out:
#     Student_ID First_Name Last_Name Grade  Age Enrollment_Date  \
# 0         3101       Emma     Scott     D   17      2017-10-01
# 1         3102    William    Turner     A   18      2020-02-24
# 2         3103      Lucas      Hill     F   18      2020-12-13
# 3         3104     Sophia    Wright     F   22      2022-04-22
# 4         3105       Liam  Anderson     B   18      2020-09-02
# ..         ...        ...       ...   ...  ...             ...
# 95        3196      James   Stewart     B   18      2017-07-05
# 96        3197       Emma     Adams     D    0      2020-08-13
# 97        3198       Liam      Hill     C  150      2017-09-30
# 98        3199        Mia    Wright     F   19      2017-07-29
# 99        3200    William     Clark     C   17      2019-12-08
#
#                Major   GPA
# 0        Engineering  3.20
# 1         Psychology  2.05
# 2   Computer Science  3.71
# 3        Engineering  3.17
# 4                Art  2.10
# ..               ...   ...
# ...

# %%
replaced
# Out:
# array([17., 18., 18., 22., 18., 21., 21., 20., 18., 19., 20., 18., 21.,
#        16., 18., 22., 19., 15., 22., 21., 15., 22., 14., 19., 22., 18.,
#        20., 14., 18., 17., 16., 20., 15., 21., 20., 18., 18., 22., 16.,
#        22., 15., 16., 17., 21., 15., 14., 22., 15., 19., 18., 16., 18.,
#        16., 20., 22., 21., 21., 20., 14., 19., 15., 18., 17., 22., 15.,
#        16., 14., 17., 16., 20., 20., 22., 21., 20., 15., 15., 14., 19.,
#        17., 14., 16., 15., 21., 20., 17., 18., 14., 19., 18., 15., 16.,
#        17., 20., 19., 17., 18., 10., 26., 19., 17., 20., 21., 14., 18.,
#        21., 19., 19., 21., 20., 17., 22., 15., 19., 16., 18., 22., 16.,
#        22., 16., 15., 22., 17., 22., 19., 18., 16., 21., 18., 15., 19.,
#        16., 17., 17., 14., 17., 22., 19., 16., 21., 17., 17., 19., 15.,
#        14., 19., 20., 20., 20., 16., 22.])

# %%
df.loc[97]
# Out:
# Student_ID               3198
# First_Name               Liam
# Last_Name                Hill
# Grade                       C
# Age                       150
# Enrollment_Date    2017-09-30
# Major                     Art
# GPA                      2.14
# Name: 97, dtype: object

# %%
df2 = pd.DataFrame({
    'Emails': ['john@iba-suk.edu.pk', 'rehan@hotmal', 'nadir@org.pk']
})

df2['Username'] = df2.Emails.str.split('@').str[0]
df2['Domain'] = df2.Emails.str.split('@').str[1]
df2
# Out:
#                 Emails Username          Domain
# 0  john@iba-suk.edu.pk     john  iba-suk.edu.pk
# 1         rehan@hotmal    rehan          hotmal
# 2         nadir@org.pk    nadir          org.pk

# %%
# Out:
#      Student_ID First_Name Last_Name Grade  Age Enrollment_Date  \
# 0          3101       Emma     Scott     D   17      2017-10-01
# 1          3102    William    Turner     A   18      2020-02-24
# 2          3103      Lucas      Hill     F   18      2020-12-13
# 3          3104     Sophia    Wright     F   22      2022-04-22
# 4          3105       Liam  Anderson     B   18      2020-09-02
# ..          ...        ...       ...   ...  ...             ...
# 145        3246      Lucas     Young     C   20      2018-02-19
# 146        3247    William   Stewart     D   20      2023-04-02
# 147        3248     Olivia  Anderson     F   20      2018-02-19
# 148        3249      Lucas   Stewart     A   16      2018-11-15
# 149        3250     Olivia   Stewart     C   22      2019-06-09
#
#                 Major   GPA
# 0         Engineering  3.20
# 1          Psychology  2.05
# 2    Computer Science  3.71
# 3         Engineering  3.17
# 4                 Art  2.10
# ...

# %%
# how to split first and last name from nameme from clomu
df['First Name'] = df['Name'].str.split(' ').str[0]
df['Last Name'] = df['Name'].str.split(' ').str[-1]

# upper the first name
