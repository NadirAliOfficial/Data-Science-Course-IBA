# %%
print("Week 3 Day 5")
# Out:
# Week 3 Day 5

# %%
import pandas as pd
data = pd.read_csv("../data/employees_data.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#    Employee_ID First_Name Last_Name  Department  Salary   Join_Date  Age  \
# 0         1101        Max     Moore     Finance   64904  2015-01-31   49
# 1         1102        Max       Doe  Operations   62488  2013-01-10   40
# 2         1103      Lucas     Black     Finance  107951  2017-05-26   52
# 3         1104    Charlie     Davis   Marketing   84243  2023-02-18   34
# 4         1105      Lucas     Black   Marketing  102331  2018-12-05   36
#
#           City
# 0       Dallas
# 1  Los Angeles
# 2     New York
# 3    San Diego
# 4      Phoenix

# %%
import matplotlib.pyplot as plt

plt.bar(df.Department, df.Salary)
plt.xlabel("Departments")
plt.ylabel("Salaries")
plt.title("Salaries of Departments")
plt.show()

# %%
maximum = df.groupby("Department")["Salary"].max()
minimum = df.groupby("Department")["Salary"].min()
plt.bar(maximum.index, maximum)
plt.bar(minimum.index, minimum)
plt.xlabel("Departments")
plt.ylabel("Salaries")
plt.title("Salaries of Departments")
plt.legend(["Maximum Salary", "Minimum Salary"])
plt.show()

# %%
department_count = df.Department.value_counts()
department_count
# Out:
# Department
# Finance       28
# IT            28
# HR            27
# Operations    25
# Marketing     22
# Sales         20
# Name: count, dtype: int64

# %%
plt.pie(department_count, labels=department_count.index, autopct="%1.0f%%", explode=[0,0.1,0,0.1,0,0.1])
plt.show()

# %%
plt.hist(df.Salary, bins=10, color='green', edgecolor='black')
plt.xlabel("Salaries")
plt.ylabel("Frequency")
plt.title("Histogram of Salaries")
plt.show()

# %%
df["Join_Date"] = pd.to_datetime(df["Join_Date"])
trend = df["Join_Date"].dt.year.value_counts().sort_index()

people = trend
plt.plot(people.index, people, marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Employees')
plt.title('Number of Employees Joined Each Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='Department', y='Salary', data=df)
plt.title('Salary Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.show()

# %%
pvt_table = df.pivot_table(index='Department', columns='City', values='Salary')
pvt_table
# Out:
# City              Chicago        Dallas        Houston    Los Angeles  \
# Department
# Finance      74182.500000  84321.666667   79285.000000  101287.666667
# HR           96609.000000  70416.833333   69855.000000            NaN
# IT           87220.400000  94737.250000  111279.000000   77888.600000
# Marketing   111418.500000  95763.000000            NaN   83097.000000
# Operations   57190.000000  72692.333333   72594.666667   75539.888889
# Sales        63217.666667  75371.666667   91119.666667   63081.666667
#
# City        New York       Phoenix  San Diego
# Department
# Finance      95448.8  99816.333333    83951.0
# HR           86032.2  82593.000000    82094.0
# IT           87562.0  84636.250000    78975.6
# Marketing    89718.0  98083.250000    76707.0
# Operations  100710.5  89992.500000    77550.2
# Sales        95042.5  71043.000000    50641.0

# %%
sns.heatmap(pvt_table, annot=True, fmt='0.0f')
plt.show()

# %%
from datetime import datetime as dt
startup = dt.now()
print(f"Startup Time: {startup.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Startup Time: 2024-12-06 19:40:33

# %%
avg_salaries = df.groupby('Department')['Salary'].mean()
plt.bar(avg_salaries.index, avg_salaries)
plt.show()

# %%
num_df = df.select_dtypes(include=['number'])
num_df.head()
corelation = num_df.corr()
corelation
                          
sns.heatmap(corelation, annot=True)
# Out:
# <Axes: >
